# %% [markdown]
# <div class="alert alert-block alert-info">
# <center>ESTATÍSTICA APLICADA</center>
# <center>Lista 12</center>
# <center>ALUNO: Diego Cardoso dos Santos</center>
# </div>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Questão 1 ##

# %%
df = pd.read_csv('dados1.csv', sep=';', decimal=',', header=None, names= list('ABCDEFGHIJ'))

# %%
notas = pd.Series(df.values.reshape(100,))

# %%
fa, classes = np.histogram(notas, bins=5)
fa = fa.astype(int)
fr = np.around(fa/fa.sum()*100,decimals=2)

classe_str = []
for i in range(len(classes)):
    if i<=len(classes)-2:
        classe_str.append('{:2.2f} |-- {:2.2f}' .format(classes[i],classes[i+1]))
    else:
        break
        
df1 = pd.DataFrame({'Notas':classe_str, 
                         'FA': fa,
                         'FR %': fr,
                        }).set_index('Notas')

df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-157-c6034f045da2> in <module>
#      10         break
#      11
# ---> 12 df1 = pd.DataFrame({'Notas':classe_str,
#      13                          'FA': fa,
#      14                          'FR %': fr,
#
# TypeError: 'dict' object is not callable

# %%
# %matplotlib inline
df1.plot.barh(title='Frequências Relativa/Absoluta')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-8cb19c9ba1b2> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 df1.plot.barh(title='Frequências Relativa/Absoluta')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in barh(self, x, y, **kwargs)
#    1197         other axis represents a measured value.
#    1198         """
# -> 1199         return self(kind="barh", x=x, y=y, **kwargs)
#    1200
#    1201     def box(self, by=None, **kwargs):
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     953                     data.columns = label_name
#     954
# --> 955         return plot_backend.plot(data, kind=kind, **kwargs)
#     956
#     957     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     276     def generate(self):
#     277         self._args_adjust()
# --> 278         self._compute_plot_data()
#     279         self._setup_subplots()
#     280         self._make_plot()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _compute_plot_data(self)
#     430             include_type.extend(["object", "category"])
#     431
# --> 432         numeric_data = data.select_dtypes(include=include_type, exclude=exclude_type)
#     433
#     434         try:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in select_dtypes(self, include, exclude)
#    3728                 include, unique_dtypes
#    3729             )
# -> 3730             keep_these &= self.dtypes.isin(included_dtypes)
#    3731
#    3732         if exclude:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __array_ufunc__(self, ufunc, method, *inputs, **kwargs)
#    1934         self, ufunc: Callable, method: str, *inputs: Any, **kwargs: Any
#    1935     ):
# -> 1936         return arraylike.array_ufunc(self, ufunc, method, *inputs, **kwargs)
#    1937
#    1938     # ideally we would define this to avoid the getattr checks, but
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in array_ufunc(self, ufunc, method, *inputs, **kwargs)
#     243
#     244     # for backwards compatibility check and potentially fallback for non-aligned frames
# --> 245     result = _maybe_fallback(ufunc, method, *inputs, **kwargs)
#     246     if result is not NotImplemented:
#     247         return result
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in _maybe_fallback(ufunc, method, *inputs, **kwargs)
#     181
#     182     n_alignable = sum(isinstance(x, NDFrame) for x in inputs)
# --> 183     n_frames = sum(isinstance(x, DataFrame) for x in inputs)
#     184
#     185     if n_alignable >= 2 and n_frames >= 1:
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in <genexpr>(.0)
#     181
#     182     n_alignable = sum(isinstance(x, NDFrame) for x in inputs)
# --> 183     n_frames = sum(isinstance(x, DataFrame) for x in inputs)
#     184
#     185     if n_alignable >= 2 and n_frames >= 1:
#
# TypeError: isinstance() arg 2 must be a type or tuple of types

# %% [markdown]
# ## Questão 2 ##
# ### Letra a) ###

# %%
df = pd.read_csv('dados2.csv', sep = ';')
df
# Out:
#          Bairro   Tipo N de quartos  Preço (mil)
# 0         Barra  Apto.            2          165
# 1         Barra  Apto.            3          240
# 2         Barra  Cobt.            3          158
# 3         Barra   Sala            0           90
# 4      Botafogo  Apto.            2          270
# 5        Catete  Apto.            1          250
# 6        Centro   Sala            1          110
# 7    Copacabana  Apto.            2          210
# 8    Copacabana  Apto.            2          200
# 9    Copacabana  Apto.            3          280
# 10     Flamengo  Apto.          >=4          330
# 11     Flamengo  Cobt.            1          180
# 12        Gávea  Apto.            3          290
# 13  Jacarepaguá  Apto.          >=4          320
# 14      Ipanema  Apto.            3          276
# 15        Lagoa  Apto.            3          254
# 16  Laranjeiras  Apto.            2          220
# 17  Laranjeiras  Apto.            2          219
# 18       Leblon  Apto.          >=4          340
# 19       Leblon  Apto.            3          260
# 20     Maracanã  Apto.          >=4          338
# 21      Recreio  Cobt.            3          290
# 22  São Conrado   Casa          >=4          430
# 23       Tijuca  Apto.            2          200
# 24       Tijuca  Apto.            2          210
# 25       Tijuca   Casa          >=4          370
# 26  Vila Isabel  Apto.            2          230

# %% [markdown]
# ### Letra b) ###

# %%
def dis_freq(x, nc='auto', titulo='Classes'):
    fa,classes= np.histogram(x, bins=nc) 
    fa = fa.astype(int)
    fr = np.around(fa/fa.sum()*100,decimals=2)
    
    classe_str = []
    for i in range(len(classes)):
        if i<=len(classes)-2:
            classe_str.append('{:2.2f} |-- {:2.2f}' .format(classes[i],classes[i+1]))
        else:
            break        
    return pd.DataFrame({titulo:classe_str, 
                         'FA': fa,
                         'FI': fr,
                        }).set_index(titulo)

# %%
df_preco = dis_freq(df['Preço (mil)'], 5, 'Preços')

#df_bairro_fr = pd.DataFrame(np.around(df['Bairro'].value_counts()/df['Bairro'].value_counts().sum()*100,decimals=2)).rename(columns={'Bairro': 'FR'})
#df_bairro_fa = pd.DataFrame(df['Bairro'].value_counts()).rename(columns={'Bairro': 'FA'})
#df_bairro = pd.DataFrame({'FA': df['Bairro'].value_counts(),
#                         'FR': np.around(df['Bairro'].value_counts()/df['Bairro'].value_counts().sum()*100,decimals=2)})

df_preco
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-6f647423633c> in <module>
# ----> 1 df_preco = dis_freq(df['Preço (mil)'], 5, 'Preços')
#       2
#       3 #df_bairro_fr = pd.DataFrame(np.around(df['Bairro'].value_counts()/df['Bairro'].value_counts().sum()*100,decimals=2)).rename(columns={'Bairro': 'FR'})
#       4 #df_bairro_fa = pd.DataFrame(df['Bairro'].value_counts()).rename(columns={'Bairro': 'FA'})
#       5 #df_bairro = pd.DataFrame({'FA': df['Bairro'].value_counts(),
#
# <ipython-input-148-5c22c2759bf6> in dis_freq(x, nc, titulo)
#      10         else:
#      11             break
# ---> 12     return pd.DataFrame({titulo:classe_str,
#      13                          'FA': fa,
#      14                          'FI': fr,
#
# TypeError: 'dict' object is not callable
